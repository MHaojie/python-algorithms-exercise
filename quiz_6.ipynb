# %%
# DO *NOT* WRITE YOUR NAME TO MAINTAIN ANONYMITY FOR PLAGIARISM DETECTION

# Prompts the user for a seed, a dimension dim, and an upper bound N.
# Randomly fills a grid of size dim x dim with numbers between 0 and N
# and computes:
# - the largest value n such that there is a path of the form (0, 1, 2,... n);
# - the number of such paths.
# A path is obtained by repeatedly moving in the grid one step north, south,
# west, or east.


import sys
from random import seed, randint
from collections import Counter
import time
def display_grid():
    for row in grid:
        print(' '.join(f'{e:{len(str(upper_bound))}}' for e in row)) 
def find_path(grid,start_point,values):
    if start_point[0]!= 0 and grid[start_point[0]-1][start_point[1]] == grid[start_point[0]][start_point[1]] + 1 :
        find_path(grid,(start_point[0]-1,start_point[1]),values)
    if start_point[0]!= len(grid)-1 and grid[start_point[0]+1][start_point[1]] == grid[start_point[0]][start_point[1]] + 1:
        find_path(grid,(start_point[0]+1,start_point[1]),values)
    if start_point[1]!= 0 and grid[start_point[0]][start_point[1]-1] == grid[start_point[0]][start_point[1]] + 1 :
        find_path(grid,(start_point[0],start_point[1]-1),values)
    if start_point[1]!= len(grid[0])-1 and grid[start_point[0]][start_point[1]+1] == grid[start_point[0]][start_point[1]] + 1:
        find_path(grid,(start_point[0],start_point[1]+1),values)
    values.append(grid[start_point[0]][start_point[1]])
    
def value_and_number_of_longest_paths():
    all_start_point = []
    for i in range(len(grid)):
        for j in range(len(grid[0])):
            if grid[i][j] == 0:
                all_start_point.append((i,j))
    i_max_value = []
    i_max_number_of_path = []
    for i in all_start_point:
        i_values = []
        find_path(grid,i,i_values)
        i_max_value.append(max(i_values))
        i_max_number_of_path.append(Counter(i_values)[max(i_values)])
    max_value = max(i_max_value)
    number_of_longest_paths = 0
    for i in range(len(i_max_value)):
        if i_max_value[i]==max_value:
            number_of_longest_paths = number_of_longest_paths + i_max_number_of_path[i]
    return max_value,number_of_longest_paths 

# POSSIBLY DEFINE OTHER FUNCTIONS
start = time.process_time()
provided_input = input('Enter three integers: ').split()
if len(provided_input) != 3:
    print('Incorrect input, giving up.')
    sys.exit()
try:
    for_seed, dim, upper_bound = (abs(int(e)) for e in provided_input)
except ValueError:
    print('Incorrect input, giving up.')
    sys.exit()
seed(for_seed)
grid = [[randint(0, upper_bound) for _ in range(dim)] for _ in range(dim)]
print('Here is the grid that has been generated:')
display_grid()

max_value, nb_of_paths_of_max_value = value_and_number_of_longest_paths()
if not nb_of_paths_of_max_value:
    print('There is no 0 in the grid.')
else:
    print('The longest paths made up of consecutive numbers starting '
          f'from 0 go up to {max_value}.'
         )
    if nb_of_paths_of_max_value == 1:
        print('There is one such path.')
    else:
        print('There are', nb_of_paths_of_max_value, 'such paths.')
end = time.process_time()
print(end-start)
# Out:
# Enter three integers: 0 1000 50
# Here is the grid that has been generated:
# The longest paths made up of consecutive numbers starting from 0 go up to 3.
# There are 7 such paths.
# 1.390625

# %%
import sys
from random import seed, randint
from collections import Counter
import time
def display_grid():
    for row in grid:
        print(' '.join(f'{e:{len(str(upper_bound))}}' for e in row)) 
def find_path(grid,start_point,values):
    a = 0
    if start_point[0]!= 0 and grid[start_point[0]-1][start_point[1]] == grid[start_point[0]][start_point[1]] + 1 :
        find_path(grid,(start_point[0]-1,start_point[1]),values)
        a += 1
    if start_point[0]!= len(grid)-1 and grid[start_point[0]+1][start_point[1]] == grid[start_point[0]][start_point[1]] + 1:
        find_path(grid,(start_point[0]+1,start_point[1]),values)
        a += 1
    if start_point[1]!= 0 and grid[start_point[0]][start_point[1]-1] == grid[start_point[0]][start_point[1]] + 1 :
        find_path(grid,(start_point[0],start_point[1]-1),values)
        a += 1
    if start_point[1]!= len(grid[0])-1 and grid[start_point[0]][start_point[1]+1] == grid[start_point[0]][start_point[1]] + 1:
        find_path(grid,(start_point[0],start_point[1]+1),values)
        a += 1
    if a == 0:
        values.append(grid[start_point[0]][start_point[1]])
    
def value_and_number_of_longest_paths():
    all_start_point = []
    each_zero_max_value = []
    each_zero_number_of_longest_path = []
    for i in range(len(grid)):
        for j in range(len(grid[0])):
            if grid[i][j] == 0:
                current_zero_values = []
                find_path(grid,(i,j),current_zero_values)
                each_zero_max_value.append(max(current_zero_values))
                each_zero_number_of_longest_path.append(Counter(current_zero_values)[max(current_zero_values)])
    max_value = max(each_zero_max_value)
    number_of_longest_paths = 0
    for i in range(len(each_zero_max_value)):
        if each_zero_max_value[i]==max_value:
            number_of_longest_paths = number_of_longest_paths + each_zero_number_of_longest_path[i]
    return max_value,number_of_longest_paths 

# POSSIBLY DEFINE OTHER FUNCTIONS
start = time.process_time()
provided_input = input('Enter three integers: ').split()
if len(provided_input) != 3:
    print('Incorrect input, giving up.')
    sys.exit()
try:
    for_seed, dim, upper_bound = (abs(int(e)) for e in provided_input)
except ValueError:
    print('Incorrect input, giving up.')
    sys.exit()
seed(for_seed)
grid = [[randint(0, upper_bound) for _ in range(dim)] for _ in range(dim)]
print('Here is the grid that has been generated:')
display_grid()

max_value, nb_of_paths_of_max_value = value_and_number_of_longest_paths()
if not nb_of_paths_of_max_value:
    print('There is no 0 in the grid.')
else:
    print('The longest paths made up of consecutive numbers starting '
          f'from 0 go up to {max_value}.'
         )
    if nb_of_paths_of_max_value == 1:
        print('There is one such path.')
    else:
        print('There are', nb_of_paths_of_max_value, 'such paths.')
end = time.process_time()
print(end - start)
# Out:
# Enter three integers: 0 1000 50
# Here is the grid that has been generated:
# The longest paths made up of consecutive numbers starting from 0 go up to 3.
# There are 7 such paths.
# 1.390625

# %%
def display_grid():
    for row in grid:
        print(' '.join(f'{e:{len(str(upper_bound))}}' for e in row)) 
def find_path(grid,start_point,values):
    if start_point[0]!= 0 and grid[start_point[0]-1][start_point[1]] == grid[start_point[0]][start_point[1]] + 1 :
        find_path(grid,(start_point[0]-1,start_point[1]),values)
    if start_point[0]!= len(grid)-1 and grid[start_point[0]+1][start_point[1]] == grid[start_point[0]][start_point[1]] + 1:
        find_path(grid,(start_point[0]+1,start_point[1]),values)
    if start_point[1]!= 0 and grid[start_point[0]][start_point[1]-1] == grid[start_point[0]][start_point[1]] + 1 :
        find_path(grid,(start_point[0],start_point[1]-1),values)
    if start_point[1]!= len(grid[0])-1 and grid[start_point[0]][start_point[1]+1] == grid[start_point[0]][start_point[1]] + 1:
        find_path(grid,(start_point[0],start_point[1]+1),values)
    values.append(grid[start_point[0]][start_point[1]])
provided_input = input('Enter three integers: ').split()
if len(provided_input) != 3:
    print('Incorrect input, giving up.')
    sys.exit()
try:
    for_seed, dim, upper_bound = (abs(int(e)) for e in provided_input)
except ValueError:
    print('Incorrect input, giving up.')
    sys.exit()
seed(for_seed)
grid = [[randint(0, upper_bound) for _ in range(dim)] for _ in range(dim)]
print('Here is the grid that has been generated:')
display_grid()
a,b = input('Enter two integers: ').split()
values = []
find_path(grid,(int(a),int(b)),values)
print(values)
# Out:
# Enter three integers: 0 8 4
# Here is the grid that has been generated:
# 3 3 0 2 4 3 3 2
# 3 2 4 1 4 1 2 1
# 0 4 2 4 4 1 2 0
# 0 2 3 4 0 2 3 2
# 4 1 4 3 3 4 2 0
# 4 0 0 3 0 4 3 2
# 1 2 0 1 4 1 1 1
# 4 3 0 0 2 4 3 0
# Enter two integers: 2 7
# [3, 2, 3, 2, 1, 0]

# %%
from collections import Counter
values = [1, 1, 1, 0]

a = max(values)
b = Counter(values)[a]
b
# Out:
# 3

# %%
import sys
from random import seed, randint
from collections import Counter
import time
def display_grid():
    for row in grid:
        print(' '.join(f'{e:{len(str(upper_bound))}}' for e in row)) 
def find_path(grid,start_point,values):
    a = 0
    if start_point[0]!= 0 and grid[start_point[0]-1][start_point[1]] == grid[start_point[0]][start_point[1]] + 1 :
        find_path(grid,(start_point[0]-1,start_point[1]),values)
        a += 1
    if start_point[0]!= len(grid)-1 and grid[start_point[0]+1][start_point[1]] == grid[start_point[0]][start_point[1]] + 1:
        find_path(grid,(start_point[0]+1,start_point[1]),values)
        a += 1
    if start_point[1]!= 0 and grid[start_point[0]][start_point[1]-1] == grid[start_point[0]][start_point[1]] + 1 :
        find_path(grid,(start_point[0],start_point[1]-1),values)
        a += 1
    if start_point[1]!= len(grid[0])-1 and grid[start_point[0]][start_point[1]+1] == grid[start_point[0]][start_point[1]] + 1:
        find_path(grid,(start_point[0],start_point[1]+1),values)
        a += 1
    if a == 0:
        values.append(grid[start_point[0]][start_point[1]])
    
def value_and_number_of_longest_paths():
    all_start_point = []
    each_zero_max_value = []
    each_zero_number_of_longest_path = []
    for i in range(len(grid)):
        for j in range(len(grid[0])):
            if grid[i][j] == 0:
                current_zero_values = []
                find_path(grid,(i,j),current_zero_values)
                each_zero_max_value.append(max(current_zero_values))
                each_zero_number_of_longest_path.append(Counter(current_zero_values)[max(current_zero_values)])
    max_value = max(each_zero_max_value)
    number_of_longest_paths = 0
    for i in range(len(each_zero_max_value)):
        if each_zero_max_value[i]==max_value:
            number_of_longest_paths = number_of_longest_paths + each_zero_number_of_longest_path[i]
    return max_value,number_of_longest_paths 

# POSSIBLY DEFINE OTHER FUNCTIONS
start = time.process_time()
provided_input = input('Enter three integers: ').split()
if len(provided_input) != 3:
    print('Incorrect input, giving up.')
    sys.exit()
try:
    for_seed, dim, upper_bound = (abs(int(e)) for e in provided_input)
except ValueError:
    print('Incorrect input, giving up.')
    sys.exit()
seed(for_seed)
grid = [[randint(0, upper_bound) for _ in range(dim)] for _ in range(dim)]
print('Here is the grid that has been generated:')
display_grid()

max_value, nb_of_paths_of_max_value = value_and_number_of_longest_paths()
if not nb_of_paths_of_max_value:
    print('There is no 0 in the grid.')
else:
    print('The longest paths made up of consecutive numbers starting '
          f'from 0 go up to {max_value}.'
         )
    if nb_of_paths_of_max_value == 1:
        print('There is one such path.')
    else:
        print('There are', nb_of_paths_of_max_value, 'such paths.')
end = time.process_time()
print(end - start)
# Out:
# Enter three integers: 0 12 2
# Here is the grid that has been generated:
# 1 1 0 1 2 1 1 1 1 1 2 0
# 2 0 1 0 0 2 1 2 2 2 0 1
# 0 2 0 2 1 1 2 0 1 1 1 2
# 2 0 2 1 1 2 1 0 2 0 0 2
# 1 2 2 2 0 2 1 1 0 2 1 2
# 0 0 2 0 0 0 2 1 0 0 1 2
# 1 0 1 2 1 2 0 2 1 2 0 2
# 2 2 1 1 0 2 1 1 2 0 1 0
# 0 0 0 2 2 1 1 0 0 2 0 0
# 0 0 2 2 2 1 2 2 1 2 0 0
# 2 2 1 2 1 1 1 2 2 2 1 0
# 1 2 0 1 2 2 1 0 0 0 2 1
# The longest paths made up of consecutive numbers starting from 0 go up to 2.
# There are 53 such paths.
# -0.015625
